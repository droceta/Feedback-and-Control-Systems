# %%
from openai import OpenAI

# Connect to LM Studio local server
client = OpenAI(
    base_url="http://127.0.0.1:1234/v1",
    api_key="lm-studio"
)

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Enter to Continue || Type 'exit' or press ESC to exit): ")

    # Exit conditions
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break

    if not query.strip():
        continue

    print("\nUser Input:", query)
    print('- ' * 50)

    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Request completion from LM Studio server
    response = client.chat.completions.create(
        model="google/gemma-4-e2b",
        messages=messages_with_history
    )

    # Capture the full AI response
    full_ai_response = response.choices[0].message.content

    # Print the AI response clearly
    print("\nAI Response:\n")
    print(full_ai_response)

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)

    print('\n' + '=' * 100 + '\n')
# Out:
# User Input: Hi, I am Dennise Roceta
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# AI Response:
#
# Hello Dennise! It's nice to meet you. How can I help you today?
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
