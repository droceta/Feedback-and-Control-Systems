# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [10,20]             #10s + 20
den = [1, 15, 50, 0]      # s^3 + 15s^2 + 50s + 0
G = ctrl.TransferFunction(num, den)
print(G)
# Out:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#        10 s + 20
#   -------------------
#   s^3 + 15 s^2 + 50 s

# %%
poles = ctrl.poles(G)
print("Poles of the transfer function:", poles)
# Out:
# Poles of the transfer function: [-10.+0.j  -5.+0.j   0.+0.j]

# %%
#Zeros are the roots of the numerator.
zeros = ctrl.zeros(G)
print("Zeros of the transfer function:", zeros)
# Out:
# Zeros of the transfer function: [-2.+0.j]

# %%
import matplotlib.pyplot as plt
ctrl.pzmap(G, grid=True, title='Pole-Zero Map')
plt.show()
